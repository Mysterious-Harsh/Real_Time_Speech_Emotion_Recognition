# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import IPython.display as ipd  # To play sound in the notebook
import os
from tqdm import tqdm
import datetime
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from keras.models import load_model
from pydub import AudioSegment, effects
from sklearn.utils import shuffle
import noisereduce as nr
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
RAVDESS = "Data/RAVDESS/audio_speech_actors_01-24/"
TESS = "Data/TESS/"
# EMOTIONS = {
#     1: 'neutral',
#     2: 'calm',
#     3: 'happy',
#     4: 'sad',
#     5: 'angry',
#     6: 'fear',
#     7: 'disgust',
#     8: 'surprise'
# }
EMOTIONS = {
    1: 'neutral',
    2: 'happy',
    3: 'sad',
    4: 'angry',
    5: 'fear',
    6: 'disgust',
    7: 'surprise'
}
SAMPLE_RATE=22050

# %%
RAVDESS_folder_names = os.listdir(RAVDESS)
RAVDESS_folder_names.sort()

file_emotions = []
file_gender = []
file_intensity = []
file_paths = []

# for i in RAVDESS_folder_names:
#     if os.path.isdir(RAVDESS + i):
#         file_names = os.listdir(RAVDESS + i)

#         for file in file_names:
#             parts = file.split('.')[0].split('-')
#             file_emotions.append(EMOTIONS[int(parts[2])])
#             # file_intensity.append(int(parts[3]))
#             if int(parts[6]) % 2 == 0:
#                 file_gender.append('female')
#             else:
#                 file_gender.append('male')
#             file_paths.append(RAVDESS + i + '/' + file)
for file in os.listdir(TESS):
    parts = file.split('.')[0].split('_')
    if parts[2] == 'ps':
        parts[2] = 'surprise'
    file_emotions.append(parts[2])
    if parts[0] == 'OAF':
        file_gender.append('male')
    else:
        file_gender.append('female')

    file_paths.append(TESS + file)
# print(file_emotions, file_gender, file_intensity, file_paths, sep="\n")

# %%
dataset = pd.DataFrame({
    'path': file_paths,
    'gender': file_gender,
    'emotion': file_emotions
})
# dataset['emotion'] = dataset['emotion'].map(EMOTIONS)
print('Shape=>', dataset.shape)
dataset.head(50)
# Out:
# Shape=> (2800, 3)
#                                path  gender   emotion
# 0      Data/TESS/YAF_wire_happy.wav  female     happy
# 1     Data/TESS/OAF_fat_disgust.wav    male   disgust
# 2    Data/TESS/OAF_bought_happy.wav    male     happy
# 3     Data/TESS/OAF_fit_neutral.wav    male   neutral
# 4       Data/TESS/YAF_dead_fear.wav  female      fear
# 5    Data/TESS/OAF_join_neutral.wav    male   neutral
# 6      Data/TESS/YAF_hall_happy.wav  female     happy
# 7    Data/TESS/YAF_hurl_neutral.wav  female   neutral
# 8      Data/TESS/OAF_king_angry.wav    male     angry
# 9       Data/TESS/OAF_rot_angry.wav    male     angry
# 10         Data/TESS/YAF_hit_ps.wav  female  surprise
# 11       Data/TESS/OAF_gaze_sad.wav    male       sad
# 12      Data/TESS/YAF_ripe_fear.wav  female      fear
# 13    Data/TESS/YAF_dog_neutral.wav  female   neutral
# 14     Data/TESS/OAF_hire_angry.wav    male     angry
# 15       Data/TESS/OAF_neat_sad.wav    male       sad
# 16      Data/TESS/YAF_gin_happy.wav  female     happy
# 17    Data/TESS/YAF_sub_neutral.wav  female   neutral
# 18      Data/TESS/OAF_mouse_sad.wav    male       sad
# 19   Data/TESS/OAF_ripe_disgust.wav    male   disgust
# 20   Data/TESS/YAF_date_disgust.wav  female   disgust
# 21      Data/TESS/YAF_hall_fear.wav  female      fear
# 22  Data/TESS/OAF_voice_disgust.wav    male   disgust
# 23   Data/TESS/YAF_laud_neutral.wav  female   neutral
# 24     Data/TESS/YAF_numb_angry.wav  female     angry
# 25     Data/TESS/YAF_cause_fear.wav  female      fear
# 26    Data/TESS/YAF_seize_angry.wav  female     angry
# 27    Data/TESS/YAF_rag_disgust.wav  female   disgust
# 28     Data/TESS/OAF_take_angry.wav    male     angry
# 29       Data/TESS/OAF_page_sad.wav    male       sad
# 30       Data/TESS/YAF_dime_sad.wav  female       sad
# 31        Data/TESS/OAF_ripe_ps.wav    male  surprise
# 32     Data/TESS/YAF_pick_angry.wav  female     angry
# 33        Data/TESS/OAF_take_ps.wav    male  surprise
# 34     Data/TESS/OAF_calm_angry.wav    male     angry
# 35     Data/TESS/OAF_third_fear.wav    male      fear
# 36   Data/TESS/OAF_fall_neutral.wav    male   neutral
# 37        Data/TESS/OAF_pain_ps.wav    male  surprise
# 38  Data/TESS/YAF_shack_neutral.wav  female   neutral
# 39       Data/TESS/OAF_yes_fear.wav    male      fear
# 40     Data/TESS/YAF_love_happy.wav  female     happy
# 41  Data/TESS/YAF_raise_disgust.wav  female   disgust
# 42      Data/TESS/OAF_peg_happy.wav    male     happy
# 43     Data/TESS/YAF_gaze_happy.wav  female     happy
# 44     Data/TESS/YAF_kite_happy.wav  female     happy
# 45   Data/TESS/OAF_rush_disgust.wav    male   disgust
# 46        Data/TESS/OAF_turn_ps.wav    male  surprise
# 47       Data/TESS/YAF_turn_sad.wav  female       sad
# 48  Data/TESS/OAF_sheep_disgust.wav    male   disgust
# 49        Data/TESS/YAF_came_ps.wav  female  surprise

# %%
dataset = shuffle(dataset)
# dataset = shuffle(dataset)

# %%
dataset.tail(10)
# Out:
#                                 path  gender   emotion
# 1028     Data/TESS/YAF_pearl_sad.wav  female       sad
# 1000   Data/TESS/OAF_chain_happy.wav    male     happy
# 1468  Data/TESS/YAF_room_disgust.wav  female   disgust
# 1626     Data/TESS/OAF_dodge_sad.wav    male       sad
# 1936       Data/TESS/OAF_void_ps.wav    male  surprise
# 2764      Data/TESS/YAF_soup_sad.wav  female       sad
# 1906  Data/TESS/OAF_dead_neutral.wav    male   neutral
# 953      Data/TESS/OAF_rag_happy.wav    male     happy
# 1272     Data/TESS/OAF_rat_happy.wav    male     happy
# 2433  Data/TESS/YAF_numb_neutral.wav  female   neutral

# %% [markdown]
# # Exploratry Data Analysis (EDA)

# %%
dataset['gender'].value_counts()
# Out:
# female    1400
# male      1400
# Name: gender, dtype: int64

# %%
dataset['emotion'].value_counts()
# Out:
# angry       400
# disgust     400
# fear        400
# sad         400
# happy       400
# surprise    400
# neutral     400
# Name: emotion, dtype: int64

# %%
dataset['emotion'].value_counts(normalize=True) * 100
# Out:
# angry       14.285714
# disgust     14.285714
# fear        14.285714
# sad         14.285714
# happy       14.285714
# surprise    14.285714
# neutral     14.285714
# Name: emotion, dtype: float64

# %%
male_sample = []
female_sample = []
for i in EMOTIONS.values():
    male_sample.append(dataset[dataset['emotion'] == i][
        dataset['gender'] == 'male']['path'].reset_index(drop=True)[0])
    female_sample.append(dataset[dataset['emotion'] == i][
        dataset['gender'] == 'female']['path'].reset_index(drop=True)[0])
print(male_sample)
print(female_sample)
# Out:
# ['Data/TESS/OAF_sheep_neutral.wav', 'Data/TESS/OAF_beg_happy.wav', 'Data/TESS/OAF_hate_sad.wav', 'Data/TESS/OAF_doll_angry.wav', 'Data/TESS/OAF_read_fear.wav', 'Data/TESS/OAF_take_disgust.wav', 'Data/TESS/OAF_lease_ps.wav']
# ['Data/TESS/YAF_knock_neutral.wav', 'Data/TESS/YAF_long_happy.wav', 'Data/TESS/YAF_pole_sad.wav', 'Data/TESS/YAF_neat_angry.wav', 'Data/TESS/YAF_goose_fear.wav', 'Data/TESS/YAF_thumb_disgust.wav', 'Data/TESS/YAF_walk_ps.wav']
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/1306359228.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_sample.append(dataset[dataset['emotion'] == i][
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/1306359228.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_sample.append(dataset[dataset['emotion'] == i][

# %%
for emotion, path in zip(EMOTIONS.values(), male_sample):
    signal, sr = librosa.load(path, sr=SAMPLE_RATE)
    print(f"Emotion:{emotion}")
    # Play the Audio
    ipd.display(ipd.Audio(signal, rate=SAMPLE_RATE))
# Out:
# Emotion:neutral
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:happy
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:sad
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:angry
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:fear
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:disgust
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:surprise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for emotion, path in zip(EMOTIONS.values(), female_sample):
    signal, sr = librosa.load(path, sr=SAMPLE_RATE)
    print(f"Emotion:{emotion}")
    # Play the Audio
    ipd.display(ipd.Audio(signal, rate=SAMPLE_RATE))
# Out:
# Emotion:neutral
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:happy
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:sad
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:angry
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:fear
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:disgust
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Emotion:surprise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, axes = plt.subplots(4, 2, figsize=(24, 22))
plt.suptitle("\n\n\nMale Samples", va='center', fontweight="bold")
for ax, emotion, path in zip(axes.flatten(), EMOTIONS.values(), male_sample):
    signal, sr = librosa.load(path, sr=SAMPLE_RATE)
    librosa.display.waveshow(signal, sr=SAMPLE_RATE, ax=ax)
    ax.set(title=emotion)

# %%
fig, axes = plt.subplots(4, 2, figsize=(24, 22))
plt.suptitle("\n\n\nFemale Samples", va='center', fontweight="bold")
for ax, emotion, path in zip(axes.flatten(), EMOTIONS.values(), female_sample):
    signal, sr = librosa.load(path, sr=SAMPLE_RATE)
    librosa.display.waveshow(signal, sr=SAMPLE_RATE, ax=ax)
    ax.set(title=emotion)

# %% [markdown]
# # Preprocessing For Single File

# %%
#Taking an audio file form male_sample to perform preprocessing to know the audio data more
path = male_sample[0]
rawsound = AudioSegment.from_file(path)
ats, sr = librosa.load(path, sr=None)
print("Sample Rate : ", sr)
plt.figure(figsize=(12, 2))
librosa.display.waveshow(ats, sr)
plt.title('Initial audio')
# Out:
# Sample Rate :  24414
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/3342237311.py:7: FutureWarning: Pass sr=24414 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(ats, sr)
# Text(0.5, 1.0, 'Initial audio')

# %%
X = librosa.stft(ats)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(18, 8))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
plt.figure(figsize=(18, 8))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
# Normalizing the audio to give audio boost to quiter part by giving +5.0 dBFS (decibels relative to full scale)
# and transforing normalized audio to Numpy array
normalizedsound = effects.normalize(rawsound, headroom=5.0)
normal_audio = np.array(normalizedsound.get_array_of_samples(),
                        dtype='float32')

plt.figure(figsize=(12, 2))
librosa.display.waveshow(normal_audio, sr)
plt.title('Normalized audio')

normalizedsound
# Out:
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/3066147956.py:8: FutureWarning: Pass sr=24414 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(normal_audio, sr)
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# Trimming the audio to remover silence before and after speech
trimmed_audio, index = librosa.effects.trim(normal_audio, top_db=30)

plt.figure(figsize=(12, 2))
librosa.display.waveshow(trimmed_audio, sr)
plt.title('Trimmed audio')

ipd.display(ipd.Audio(data=trimmed_audio, rate=sr))
# Out:
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/3826362084.py:5: FutureWarning: Pass sr=24414 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(trimmed_audio, sr)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Padding some values to right side to make all data length equal
# so we have maximum lenght audio file with 173056

padded_audio = np.pad(trimmed_audio, (0, 228864 - len(trimmed_audio)),
                      'constant')

plt.figure(figsize=(12, 2))
librosa.display.waveshow(padded_audio, sr)
plt.title('Padded audio')

ipd.display(ipd.Audio(data=padded_audio, rate=sr))
# Out:
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/2925237830.py:8: FutureWarning: Pass sr=24414 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(padded_audio, sr)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Eliminating noise from audio by performing Noise Reduction
final_audio = nr.reduce_noise(padded_audio, sr)

plt.figure(figsize=(12, 2))
librosa.display.waveshow(final_audio, sr)
plt.title('Reduced Noise audio')

ipd.display(ipd.Audio(data=final_audio, rate=sr))
# Out:
# /var/folders/y6/4njssq5s2_764zsxh2lpvlvm0000gn/T/ipykernel_41665/610437427.py:5: FutureWarning: Pass sr=24414 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(final_audio, sr)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature Selection For Single File

# %%
f1 = librosa.feature.rms(y=final_audio)  # Energy - Root Mean Square (RMS)
print('Energy shape:', f1.shape)

f2 = librosa.feature.zero_crossing_rate(
    y=final_audio)  # Zero Crossed Rate (ZCR)
print('ZCR shape:', f2.shape)

f3 = librosa.feature.mfcc(y=final_audio, sr=sr)  # MFCCs
print('MFCCs shape:', f3.shape)
plt.figure(figsize=(15, 7))
librosa.display.specshow(f3, sr=sr, x_axis='time')

f4 = librosa.feature.spectral_centroid(y=final_audio,
                                       sr=sr)  # pectral centroid
print('Spectral Centroid shape:', f4.shape)

f5 = librosa.feature.chroma_stft(y=final_audio, sr=sr)  # chroma feature
print('chroma feature shape:', f5.shape)
plt.figure(figsize=(15, 5))
librosa.display.specshow(f5, x_axis='time', y_axis='chroma', cmap='coolwarm')
# Out:
# Energy shape: (1, 448)
# ZCR shape: (1, 448)
# MFCCs shape: (20, 448)
# Spectral Centroid shape: (1, 448)
# chroma feature shape: (12, 448)

# %% [raw]
# # Maximum samples count for padding purposes.
# sample_lengths = []
# max_length = 0
# d=[]
# for path in dataset['path']:
#     x, sr = librosa.load(
#         path=path)
#     # x = AudioSegment.from_file(path)
#     # normal_audio = np.array(x.get_array_of_samples(), dtype='float32')
#     xt, index = librosa.effects.trim(x, top_db=30)
#     dur=librosa.get_duration(y=xt)
#     d.append(dur)
#
#     sample_lengths.append(len(xt))
# max_length = max(sample_lengths)
# print('Maximum sample length:', max(sample_lengths))

# %% [raw]
# sum(d)/len(d)

# %%
import time

tic = time.perf_counter()
# scaler = StandardScaler()

# Initialize data lists
rms = []
# zcr = []
mfcc = []
# sc = []
cf = []
mel = []
emotions = []
max_length = 65303
frame_length = 2048
hop_length = 512
sr = 22050
for path, emotion in dataset[['path', 'emotion']].to_numpy():

    # Fetch the sample rate.
    rawsound, _ = librosa.load(
        path=path)
    # print(sr)
    # sr (the sample rate) is used for librosa's MFCCs. '_' is irrelevant.
    # Load the audio file.
    # rawsound = AudioSegment.from_file(path)
    # Normalize the audio to +5.0 dBFS.
    # normalizedsound = effects.normalize(rawsound, headroom=5.0)
    normalizedsound = librosa.util.normalize(rawsound)
    # Transform the normalized audio to np.array of samples.
    # normal_audio = np.array(normalizedsound.get_array_of_samples(),
    #                         dtype='float32')
    # Trim silence from the beginning and the end.
    trimmed_audio, index = librosa.effects.trim(y=normalizedsound, top_db=30)
    # print(len(trimmed_audio))
    # Pad for duration equalization.
    if len(trimmed_audio) > max_length:
        continue
    final_audio = np.pad(trimmed_audio, (0, max_length - len(trimmed_audio)),
                          'constant')
    # Noise reduction.
    # final_audio = nr.reduce_noise(y=padded_audio, sr=sr)  #updated 03/03/22

    # Features extraction
    f1 = librosa.feature.rms(
        y=final_audio, frame_length=frame_length,
        hop_length=hop_length).T  # Energy - Root Mean Square
    # f2 = librosa.feature.zero_crossing_rate(y=final_audio,
    #                                         frame_length=frame_length,
    #                                         hop_length=hop_length,
    #                                         center=True).T  # ZCR
    f3 = librosa.feature.mfcc(y=final_audio,
                              sr=sr,
                              n_mfcc=80,
                              hop_length=hop_length).T  # MFCC

    # f4 = librosa.feature.spectral_centroid(
    #     y=final_audio, sr=sr, hop_length=hop_length).T  # pectral centroid

    f5 = librosa.feature.chroma_stft(y=final_audio, sr=sr).T  # chroma feature
    f6 = librosa.feature.melspectrogram(y=final_audio,
                                        n_fft=frame_length,
                                        hop_length=hop_length).T

    # Filling the data lists

    rms.append(f1)
    # zcr.append(scaler.fit_transform(f2))
    mfcc.append(f3)
    # sc.append(f4)
    cf.append(f5)
    mel.append(f6)
    emotions.append(tuple(EMOTIONS.values()).index(emotion))
    
f_rms = np.asarray(rms)
# f_zcr = np.asarray(zcr)
f_mfccs = np.asarray(mfcc)
# f_sc = np.asarray(sc)
f_cf = np.asarray(cf)
f_mel = np.asarray(mel)
# Concatenating all features to 'X' variable.
X = np.concatenate(( f_rms,f_mfccs,f_sc,f_cf,f_mel), axis=2)
# Preparing 'Y' as a 2D shaped variable.
Y = np.asarray(emotions)
Y = np.expand_dims(Y, axis=1)
enc = OneHotEncoder()
Y = enc.fit_transform(Y)
Y = Y.toarray()
toc = time.perf_counter()
print(f"Running time: {(toc - tic)/60:0.4f} minutes")
# Out:
# Running time: 2.9357 minutes

# %%
# f_rms = np.asarray(rms).astype('float32')
# f_rms = np.swapaxes(f_rms, 1, 2)
# f_zcr = np.asarray(zcr).astype('float32')
# f_zcr = np.swapaxes(f_zcr, 1, 2)
# f_mfccs = np.asarray(mfcc).astype('float32')
# f_mfccs = np.swapaxes(f_mfccs, 1, 2)
# f_sc = np.asarray(sc).astype('float32')
# f_sc = np.swapaxes(f_sc, 1, 2)
# f_cf = np.asarray(cf).astype('float32')
# f_cf = np.swapaxes(f_cf, 1, 2)

# print('ZCR shape:', f_zcr.shape)
print('RMS shape:', f_rms.shape)
print('MFCCs shape:', f_mfccs.shape)
print('SC shape:', f_sc.shape)
print('CF shape:', f_cf.shape)
print('mel shape:', f_mel.shape)

print('X shape:', X.shape)
print('Y shape:', Y.shape)
# Out:
# RMS shape: (2800, 128, 1)
# MFCCs shape: (2800, 128, 80)
# SC shape: (2800, 128, 1)
# CF shape: (2800, 128, 12)
# mel shape: (2800, 128, 128)
# X shape: (2800, 128, 222)
# Y shape: (2800, 7)

# %%
np.min(X), np.max(X)
# Out:
# (-637.6939086914062, 8569.981518921168)

# %%
# # Concatenating all features to 'X' variable.
# X = np.concatenate((f_zcr, f_rms, f_mfccs, f_sc, f_cf), axis=2)
# # Preparing 'Y' as a 2D shaped variable.
# Y = np.asarray(emotions).astype('int8')
# Y = np.expand_dims(Y, axis=1)

# %%
# # Saving Numpy arrays as Features and Labels
np.save('Features.npy', X)
np.save('Labels.npy', Y)

# %%
# X = np.load('Features.npy')
# Y = np.load('Labels.npy')

# %% [markdown]
# # Model Training

# %%
from keras.models import Sequential
import tensorflow as tf
from keras import layers
from keras import optimizers
from keras import callbacks
from keras.layers import Dropout
from keras.layers import LSTM, Dense

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Initializing the model

model = Sequential()
model.add(layers.LSTM(192, return_sequences=True, input_shape=(X.shape[1:3])))
# model.add(layers.LSTM(192, return_sequences=True))
# model.add(layers.LSTM(256,return_sequences=True))
# model.add(layers.LSTM(192, return_sequences=True))
# model.add(layers.LSTM(32))

# model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.LSTM(192))


# model.add(layers.Dropout(0.2))
# model.add(layers.Dense(390, activation='relu'))
# model.add(layers.Dropout(0.2))
# model.add(layers.Dense(128, activation='relu'))
# model.add(layers.Dropout(0.2))
# model.add(layers.Dense(28, activation='relu'))
# model.add(layers.Dropout(0.2))
# model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))

model.add(layers.Dense(7, activation='softmax'))
print(model.summary())

batch_size = 256

# Callbacks functions
checkpoint_path = 'Models/best_weights.hdf5'

#-> Save the best weights
mcp_save = callbacks.ModelCheckpoint(checkpoint_path,
                                     save_best_only=True,
                                     monitor='val_categorical_accuracy',
                                     mode='max')
#-> Reduce learning rate after 100 epoches without improvement.
rlrop = callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',
                                    factor=0.01,
                                    patience=20)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_25 (LSTM)              (None, 128, 192)          318720
#
#  lstm_26 (LSTM)              (None, 192)               295680
#
#  dense_23 (Dense)            (None, 16)                3088
#
#  dense_24 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 617,607
# Trainable params: 617,607
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.RMSprop(learning_rate=0.001)

model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['categorical_accuracy'])
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,
                                                      histogram_freq=1)

history = model.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=batch_size,
                    validation_data=(X_test, y_test),
                    callbacks=[mcp_save, rlrop, tensorboard_callback],
                    shuffle=True)
# Define the best weights to the model.
model.load_weights(checkpoint_path)
# Out:
# Epoch 1/100
# 2022-07-20 16:13:21.743903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:21.950110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:22.110266: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:22.320117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:22.640204: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - ETA: 0s - loss: 1.8779 - categorical_accuracy: 0.2071
# 2022-07-20 16:13:24.843657: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:24.929911: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:13:25.095296: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 5s 334ms/step - loss: 1.8779 - categorical_accuracy: 0.2071 - val_loss: 1.7203 - val_categorical_accuracy: 0.3196 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 1s 143ms/step - loss: 1.5926 - categorical_accuracy: 0.3201 - val_loss: 1.3716 - val_categorical_accuracy: 0.3804 - lr: 0.0010
# Epoch 3/100
# 9/9 [==============================] - 1s 129ms/step - loss: 1.2726 - categorical_accuracy: 0.4781 - val_loss: 1.0642 - val_categorical_accuracy: 0.5143 - lr: 0.0010
# Epoch 4/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.9259 - categorical_accuracy: 0.6839 - val_loss: 0.6915 - val_categorical_accuracy: 0.7464 - lr: 0.0010
# Epoch 5/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.5967 - categorical_accuracy: 0.8058 - val_loss: 0.4979 - val_categorical_accuracy: 0.8089 - lr: 0.0010
# Epoch 6/100
# 9/9 [==============================] - 1s 135ms/step - loss: 0.4498 - categorical_accuracy: 0.8330 - val_loss: 0.4160 - val_categorical_accuracy: 0.8625 - lr: 0.0010
# Epoch 7/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.3471 - categorical_accuracy: 0.8813 - val_loss: 0.3291 - val_categorical_accuracy: 0.8982 - lr: 0.0010
# Epoch 8/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.2624 - categorical_accuracy: 0.9143 - val_loss: 0.3502 - val_categorical_accuracy: 0.8661 - lr: 0.0010
# Epoch 9/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.1999 - categorical_accuracy: 0.9366 - val_loss: 0.2522 - val_categorical_accuracy: 0.9232 - lr: 0.0010
# Epoch 10/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.1250 - categorical_accuracy: 0.9616 - val_loss: 0.2412 - val_categorical_accuracy: 0.9179 - lr: 0.0010
# Epoch 11/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.1236 - categorical_accuracy: 0.9629 - val_loss: 0.1924 - val_categorical_accuracy: 0.9429 - lr: 0.0010
# Epoch 12/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0919 - categorical_accuracy: 0.9750 - val_loss: 0.1996 - val_categorical_accuracy: 0.9411 - lr: 0.0010
# Epoch 13/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.0671 - categorical_accuracy: 0.9804 - val_loss: 0.1885 - val_categorical_accuracy: 0.9464 - lr: 0.0010
# Epoch 14/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0798 - categorical_accuracy: 0.9781 - val_loss: 0.1748 - val_categorical_accuracy: 0.9429 - lr: 0.0010
# Epoch 15/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0883 - categorical_accuracy: 0.9723 - val_loss: 0.1786 - val_categorical_accuracy: 0.9500 - lr: 0.0010
# Epoch 16/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0852 - categorical_accuracy: 0.9714 - val_loss: 0.1238 - val_categorical_accuracy: 0.9536 - lr: 0.0010
# Epoch 17/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0752 - categorical_accuracy: 0.9768 - val_loss: 0.1441 - val_categorical_accuracy: 0.9571 - lr: 0.0010
# Epoch 18/100
# 9/9 [==============================] - 1s 127ms/step - loss: 0.0564 - categorical_accuracy: 0.9857 - val_loss: 0.1484 - val_categorical_accuracy: 0.9554 - lr: 0.0010
# Epoch 19/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0379 - categorical_accuracy: 0.9902 - val_loss: 0.1667 - val_categorical_accuracy: 0.9500 - lr: 0.0010
# Epoch 20/100
# 9/9 [==============================] - 1s 133ms/step - loss: 0.0293 - categorical_accuracy: 0.9920 - val_loss: 0.1501 - val_categorical_accuracy: 0.9643 - lr: 0.0010
# Epoch 21/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0209 - categorical_accuracy: 0.9951 - val_loss: 0.1052 - val_categorical_accuracy: 0.9732 - lr: 0.0010
# Epoch 22/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.0133 - categorical_accuracy: 0.9955 - val_loss: 0.0837 - val_categorical_accuracy: 0.9786 - lr: 0.0010
# Epoch 23/100
# 9/9 [==============================] - 1s 127ms/step - loss: 0.0084 - categorical_accuracy: 0.9982 - val_loss: 0.0998 - val_categorical_accuracy: 0.9750 - lr: 0.0010
# Epoch 24/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0142 - categorical_accuracy: 0.9969 - val_loss: 0.0929 - val_categorical_accuracy: 0.9732 - lr: 0.0010
# Epoch 25/100
# 9/9 [==============================] - 1s 128ms/step - loss: 0.0141 - categorical_accuracy: 0.9960 - val_loss: 0.1814 - val_categorical_accuracy: 0.9607 - lr: 0.0010
# Epoch 26/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0403 - categorical_accuracy: 0.9893 - val_loss: 0.2145 - val_categorical_accuracy: 0.9429 - lr: 0.0010
# Epoch 27/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0388 - categorical_accuracy: 0.9893 - val_loss: 0.0921 - val_categorical_accuracy: 0.9714 - lr: 0.0010
# Epoch 28/100
# 9/9 [==============================] - 1s 127ms/step - loss: 0.0692 - categorical_accuracy: 0.9786 - val_loss: 0.1371 - val_categorical_accuracy: 0.9607 - lr: 0.0010
# Epoch 29/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0433 - categorical_accuracy: 0.9866 - val_loss: 0.1459 - val_categorical_accuracy: 0.9536 - lr: 0.0010
# Epoch 30/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0291 - categorical_accuracy: 0.9920 - val_loss: 0.0945 - val_categorical_accuracy: 0.9679 - lr: 0.0010
# Epoch 31/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0154 - categorical_accuracy: 0.9964 - val_loss: 0.1018 - val_categorical_accuracy: 0.9732 - lr: 0.0010
# Epoch 32/100
# 9/9 [==============================] - 1s 128ms/step - loss: 0.0090 - categorical_accuracy: 0.9996 - val_loss: 0.0666 - val_categorical_accuracy: 0.9839 - lr: 0.0010
# Epoch 33/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0075 - categorical_accuracy: 0.9982 - val_loss: 0.0836 - val_categorical_accuracy: 0.9768 - lr: 0.0010
# Epoch 34/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0911 - categorical_accuracy: 0.9750 - val_loss: 0.1087 - val_categorical_accuracy: 0.9714 - lr: 0.0010
# Epoch 35/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0533 - categorical_accuracy: 0.9795 - val_loss: 0.0646 - val_categorical_accuracy: 0.9786 - lr: 0.0010
# Epoch 36/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0229 - categorical_accuracy: 0.9946 - val_loss: 0.0649 - val_categorical_accuracy: 0.9768 - lr: 0.0010
# Epoch 37/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0179 - categorical_accuracy: 0.9960 - val_loss: 0.1091 - val_categorical_accuracy: 0.9750 - lr: 0.0010
# Epoch 38/100
# 9/9 [==============================] - 1s 134ms/step - loss: 0.0083 - categorical_accuracy: 0.9987 - val_loss: 0.0777 - val_categorical_accuracy: 0.9786 - lr: 0.0010
# Epoch 39/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0065 - categorical_accuracy: 0.9996 - val_loss: 0.0705 - val_categorical_accuracy: 0.9839 - lr: 0.0010
# Epoch 40/100
# 9/9 [==============================] - 1s 127ms/step - loss: 0.0042 - categorical_accuracy: 0.9987 - val_loss: 0.0545 - val_categorical_accuracy: 0.9786 - lr: 0.0010
# Epoch 41/100
# 9/9 [==============================] - 1s 128ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 0.0635 - val_categorical_accuracy: 0.9857 - lr: 0.0010
# Epoch 42/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.0023 - categorical_accuracy: 0.9996 - val_loss: 0.0461 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 43/100
# 9/9 [==============================] - 1s 128ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.0486 - val_categorical_accuracy: 0.9839 - lr: 0.0010
# Epoch 44/100
# 9/9 [==============================] - 1s 129ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.0518 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 45/100
# 9/9 [==============================] - 1s 128ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.0626 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 46/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 0.0636 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 47/100
# 9/9 [==============================] - 1s 127ms/step - loss: 9.5234e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0633 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 48/100
# 9/9 [==============================] - 1s 125ms/step - loss: 8.7248e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0627 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 49/100
# 9/9 [==============================] - 1s 127ms/step - loss: 8.0800e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0623 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 50/100
# 9/9 [==============================] - 1s 125ms/step - loss: 7.5520e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0618 - val_categorical_accuracy: 0.9875 - lr: 0.0010
# Epoch 51/100
# 9/9 [==============================] - 1s 126ms/step - loss: 7.0999e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0613 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 52/100
# 9/9 [==============================] - 1s 128ms/step - loss: 6.7069e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0605 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 53/100
# 9/9 [==============================] - 1s 126ms/step - loss: 6.3604e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0593 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 54/100
# 9/9 [==============================] - 1s 128ms/step - loss: 6.0471e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0570 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 55/100
# 9/9 [==============================] - 1s 125ms/step - loss: 5.7613e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0550 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 56/100
# 9/9 [==============================] - 1s 126ms/step - loss: 5.5015e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0537 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 57/100
# 9/9 [==============================] - 1s 127ms/step - loss: 5.2631e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0529 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 58/100
# 9/9 [==============================] - 1s 125ms/step - loss: 5.0457e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0526 - val_categorical_accuracy: 0.9893 - lr: 0.0010
# Epoch 59/100
# 9/9 [==============================] - 1s 126ms/step - loss: 4.8431e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0524 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 60/100
# 9/9 [==============================] - 1s 127ms/step - loss: 4.6575e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0523 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 61/100
# 9/9 [==============================] - 1s 127ms/step - loss: 4.4831e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0523 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 62/100
# 9/9 [==============================] - 1s 125ms/step - loss: 4.3210e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0523 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 63/100
# 9/9 [==============================] - 1s 128ms/step - loss: 4.1691e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0524 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 64/100
# 9/9 [==============================] - 1s 125ms/step - loss: 4.0267e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 0.0010
# Epoch 65/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9473e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 66/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9460e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 67/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9446e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 68/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9433e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 69/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9419e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 70/100
# 9/9 [==============================] - 1s 131ms/step - loss: 3.9406e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 71/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9392e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 72/100
# 9/9 [==============================] - 1s 130ms/step - loss: 3.9378e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 73/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9364e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 74/100
# 9/9 [==============================] - 1s 129ms/step - loss: 3.9350e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 75/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9336e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 76/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.9321e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 77/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.9307e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 78/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9292e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 79/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9277e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 80/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9262e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 81/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9247e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 82/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9232e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 83/100
# 9/9 [==============================] - 1s 129ms/step - loss: 3.9217e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 84/100
# 9/9 [==============================] - 1s 129ms/step - loss: 3.9201e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 85/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 86/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 87/100
# 9/9 [==============================] - 1s 132ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 88/100
# 9/9 [==============================] - 1s 132ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 89/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 90/100
# 9/9 [==============================] - 1s 137ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 91/100
# 9/9 [==============================] - 1s 133ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 92/100
# 9/9 [==============================] - 1s 133ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 93/100
# 9/9 [==============================] - 1s 132ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 94/100
# 9/9 [==============================] - 1s 128ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 95/100
# 9/9 [==============================] - 1s 138ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 96/100
# 9/9 [==============================] - 1s 135ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 97/100
# 9/9 [==============================] - 1s 131ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 98/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 99/100
# 9/9 [==============================] - 1s 126ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07
# Epoch 100/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.9192e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0525 - val_categorical_accuracy: 0.9911 - lr: 1.0000e-07

# %%
model = load_model('Models/best_weights.hdf5')
model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['categorical_accuracy'])

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=2)
# Out:
# 2022-07-20 16:15:23.393134: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:15:23.473263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-20 16:15:23.625188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 18/18 - 1s - loss: 0.0518 - categorical_accuracy: 0.9911 - 1s/epoch - 82ms/step

# %%
loss, acc = model.evaluate(X, Y, verbose=2)

# %%
tf.keras.utils.plot_model(model,
                          to_file='model.png',
                          show_shapes=True,
                          show_layer_names=True)
