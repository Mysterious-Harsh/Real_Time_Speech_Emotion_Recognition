# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd  # To play sound in the notebook
import pyaudio
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib.animation import FuncAnimation
from keras.models import load_model
from pydub import AudioSegment, effects
import noisereduce as nr
import time
import math
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# %matplotlib widget
# %matplotlib qt
plt.rcParams['animation.html'] = 'jshtml'

# %%
def plot():
    fig, ax = plt.subplots(1, 2, figsize=(14, 8))
    plt.show()
    return fig, ax

# %%
class emotion_detector:
    # ['angry', 'calm', 'disgust', 'fear', 'happy', 'sad', 'surprise']
    def __init__(self, modelpath, threshold=122):
        self.MODEL = load_model(modelpath)
        EMOTIONS = {
            0: 'angry',
            1: 'calm',
            2: 'disgust',
            3: 'fear',
            4: 'happy',
            5: 'sad',
            6: 'surprise'
        }
        self.ENC = OneHotEncoder()
        self.ENC.fit_transform([['angry'], ['calm'], ['disgust'], ['fear'],
                                ['happy'], ['sad'], ['surprise']])
        self.THRESHOLD = threshold
        self.FORMAT = pyaudio.paFloat32
        self.CHANNELS = 1
        self.RATE = 22050
        self.CHUNK = 1024 * 4
        self.COLORS = [
            'lightblue', 'green', 'yellow', 'red', 'darkred', 'peru',
            'lightpink'
        ]
        self.EMOTION_LIST = list(EMOTIONS.values())
        self.predictions = [0, 0, 0, 0, 0, 0, 0]
        self.LENGTH = 121212  #65303
        self.FRAME_LENGTH = 2048
        self.HOP_LENGTH = 512
        self.RECORD_SECONDS = 2.5
        self.SCALER = StandardScaler()
        self.FIG, self.AX = fig, ax

    def show_emotions(self, i, predictions, emotion):
        self.AX[i].clear()
        self.AX[i].bar(self.EMOTION_LIST, predictions, color=self.COLORS)
        # self.AX[i].title.set_text(emotion)
        plt.suptitle("\n\n\n" + emotion.capitalize(),
                     va='center',
                     fontweight="bold")
        self.FIG.canvas.draw()

    def show_sound_wave(self, i, audio):
        self.AX[i].clear()
        librosa.display.waveshow(y=audio, sr=self.RATE, ax=self.AX[i])
        self.FIG.canvas.draw()

    def extract_features(self, audio):
        rms = []
        mfcc = []
        mel = []

        # Fetch the sample rate.
        normalizedsound = librosa.util.normalize(audio)

        # Trim silence from the beginning and the end.
        trimmed_audio, index = librosa.effects.trim(y=normalizedsound,
                                                    top_db=30)

        padded_audio = np.pad(trimmed_audio,
                              (0, self.LENGTH - len(trimmed_audio)), 'constant')
        # Noise reduction.
        final_audio = nr.reduce_noise(y=padded_audio,
                                      sr=self.RATE)  #updated 03/03/22

        f1 = librosa.feature.rms(
            y=final_audio,
            frame_length=self.FRAME_LENGTH,
            hop_length=self.HOP_LENGTH).T  # Energy - Root Mean Square

        f2 = librosa.feature.melspectrogram(y=final_audio,
                                            n_fft=self.FRAME_LENGTH,
                                            hop_length=self.HOP_LENGTH).T

        f3 = librosa.feature.mfcc(y=final_audio,
                                  sr=self.RATE,
                                  n_mfcc=80,
                                  hop_length=self.HOP_LENGTH).T  # MFCC

        # Filling the data lists

        rms.append(self.SCALER.fit_transform(f1))
        mel.append(self.SCALER.fit_transform(f2))
        mfcc.append(self.SCALER.fit_transform(f3))

        f_rms = np.asarray(rms)
        f_mel = np.asarray(mel)
        f_mfccs = np.asarray(mfcc)

        # Concatenating all features to 'X' variable.
        features = np.concatenate((f_rms, f_mel, f_mfccs), axis=2)
        return features

    def emotion(self, audio_features):
        predictions = self.MODEL.predict(audio_features,
                                         use_multiprocessing=True)
        pred_list = list(predictions)
        predictions = np.squeeze(np.array(pred_list).tolist(), axis=0)

        max_emo = self.ENC.inverse_transform(predictions)
        return predictions, self.EMOTION_LIST[max_emo]

    def from_file(self, file):
        audio_data = librosa.load(file)
        n = len(audio_data) / self.LENGTH
        if n < 1:
            self.show_sound_wave(1, audio_data)
            features = self.extract_features(audio_data)
            predictions, emotion = self.emotion(features)
            self.show_emotions(0, predictions, emotion)

        else:
            for i in range(math.floor(n)):
                audio = audio_data[self.LENGTH * i:self.LENGTH * (i + 1)]
                self.show_sound_wave(1, audio)
                features = self.extract_features()
                predictions, emotion = self.emotion(features)
                self.show_emotions(0, predictions, emotion)
            else:
                audio = audio_data[self.LENGTH * i:]
                self.show_sound_wave(1, audio)
                features = self.extract_features(audio)
                predictions, emotion = self.emotion(features)
                self.show_emotions(0, predictions, emotion)

    def list_devices(self):
        print("----------------------record device list---------------------")
        info = self.AUDIO.get_host_api_info_by_index(0)
        numdevices = info.get('deviceCount')
        for i in range(0, numdevices):
            if (self.AUDIO.get_device_info_by_host_api_device_index(
                    0, i).get('maxInputChannels')) > 0:
                print(
                    "Input Device id ", i, " - ",
                    self.AUDIO.get_device_info_by_host_api_device_index(
                        0, i).get('name'))

        print("-------------------------------------------------------------")

        index = int(input())
        return index

    def silence(self, audio):
        threshold = (sum(audio) / len(audio))
        print(threshold)
        return (sum(audio) / len(audio)) < self.THRESHOLD

    def start_stream(self, device_index=None):
        self.AUDIO = pyaudio.PyAudio()
        if device_index == None:
            index = self.list_devices()
        print("recording via index " + str(index))

        self.STREAM = self.AUDIO.open(format=self.FORMAT,
                                      channels=self.CHANNELS,
                                      rate=self.RATE,
                                      input=True,
                                      input_device_index=index,
                                      frames_per_buffer=self.CHUNK)
        try:
            while True:
                # print ("recording started")
                Recordframes = []

                for i in range(
                        0, int(self.RATE / self.CHUNK * self.RECORD_SECONDS)):
                    data = self.STREAM.read(self.CHUNK,
                                            exception_on_overflow=False)
                    Recordframes.append(data)
                # print ("recording stopped")
                audio = np.frombuffer(b''.join(Recordframes), dtype=np.float32)
                self.show_sound_wave(1, audio)
                if self.silence(Recordframes[-1]):
                    print("Silence Detected !")
                    self.show_emotions(0, [0, 0, 0, 0, 0, 0, 0], "Silence")
                else:
                    self.show_sound_wave(1, audio)
                    features = self.extract_features(audio)
                    predictions, emotion = self.emotion(features)
                    print(emotion)
                    self.show_emotions(0, predictions, emotion)
        except KeyboardInterrupt:
            self.STREAM.stop_stream()
            self.STREAM.close()
            self.AUDIO.terminate()
        except Exception as e:
            print(e)
            self.STREAM.stop_stream()
            self.STREAM.close()
            self.AUDIO.terminate()

    def stop_stream(self):
        self.STREAM.stop_stream()
        self.STREAM.close()
        self.AUDIO.terminate()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 8))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ed = emotion_detector('Models/1.hdf5')
try:
    ed.start_stream()
except:
    ed.stop_stream()
# Out:
# ----------------------record device list---------------------
# Input Device id  0  -  MacBook Pro Microphone
# Input Device id  2  -  Kishan’s AirPods Pro 🦁
# Input Device id  4  -  Microsoft Teams Audio
# -------------------------------------------------------------
#  2
# recording via index 2
# ||PaMacCore (AUHAL)|| Warning on line 521: err=''!obj'', msg=Unknown Error
# ||PaMacCore (AUHAL)|| Warning on line 441: err=''!obj'', msg=Unknown Error
# ||PaMacCore (AUHAL)|| Error on line 1322: err='-10851', msg=Audio Unit: Invalid Property Value
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       2 try:
# ----> 3     ed.start_stream()
#       4 except:
#
# Input In [36], in emotion_detector.start_stream(self, device_index)
#     146 print("recording via index " + str(index))
# --> 148 self.STREAM = self.AUDIO.open(format=self.FORMAT,
#     149                               channels=self.CHANNELS,
#     150                               rate=self.RATE,
#     151                               input=True,
#     152                               input_device_index=index,
#     153                               frames_per_buffer=self.CHUNK)
#     154 try:
#
# File ~/opt/miniforge3/lib/python3.9/site-packages/pyaudio.py:750, in PyAudio.open(self, *args, **kwargs)
#     743 """
#     744 Open a new stream. See constructor for
#     745 :py:func:`Stream.__init__` for parameter details.
#     746
#     747 :returns: A new :py:class:`Stream`
#     748 """
# --> 750 stream = Stream(self, *args, **kwargs)
#     751 self._streams.add(stream)
#
# File ~/opt/miniforge3/lib/python3.9/site-packages/pyaudio.py:441, in Stream.__init__(self, PA_manager, rate, channels, format, input, output, input_device_index, output_device_index, frames_per_buffer, start, input_host_api_specific_stream_info, output_host_api_specific_stream_info, stream_callback)
#     440 # calling pa.open returns a stream object
# --> 441 self._stream = pa.open(**arguments)
#     443 self._input_latency = self._stream.inputLatency
#
# OSError: [Errno -9986] Internal PortAudio error
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       3     ed.start_stream()
#       4 except:
# ----> 5     ed.stop_stream()
#
# Input In [36], in emotion_detector.stop_stream(self)
#     186 def stop_stream(self):
# --> 187     self.STREAM.stop_stream()
#     188     self.STREAM.close()
#     189     self.AUDIO.terminate()
#
# AttributeError: 'emotion_detector' object has no attribute 'STREAM'
