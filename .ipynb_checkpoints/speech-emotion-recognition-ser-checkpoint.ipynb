# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: label, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveshow(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# emotion = 'fear'
# path = np.array(df['speech'][df['label']==emotion])[0]
# data, sampling_rate = librosa.load(path)
# waveplot(data, sampling_rate, emotion)
# spectogram(data, sampling_rate, emotion)
# Audio(path)

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-286.02707   ,   86.23414   ,   -2.635008  ,   22.56944   ,
#         -15.209238  ,   11.531056  ,   11.94983   ,   -2.564069  ,
#           0.63499844,   11.539477  ,  -17.85487   ,   -7.673546  ,
#           6.1565228 ,   -3.800448  ,   -9.552902  ,    3.9220483 ,
#         -13.588675  ,   14.449348  ,   19.31697   ,   23.08124   ,
#          32.217903  ,   16.650953  ,   -4.1388583 ,    1.2018498 ,
#         -11.535383  ,    6.9179306 ,   -2.840763  ,   -7.467058  ,
#         -11.169154  ,   -2.1890633 ,   -5.489987  ,    4.463149  ,
#         -11.367347  ,   -8.866391  ,   -3.8222969 ,    5.000417  ,
#          -1.7143743 ,    2.664231  ,   11.361882  ,   11.313575  ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-286.02707, 86.23414, -2.635008, 22.56944, -1...
# 1       [-348.7427, 35.7786, -4.4302225, 15.252253, 5....
# 2       [-340.4982, 54.36257, -14.845928, 21.453777, 8...
# 3       [-307.126, 21.987495, -5.1469626, 7.2266827, -...
# 4       [-345.27826, 47.107338, -24.942877, 20.17883, ...
#                               ...
# 5595    [-374.88943, 61.58835, -0.70487076, 9.159214, ...
# 5596    [-314.5199, 40.65166, -6.461393, -3.0599391, -...
# 5597    [-358.06696, 78.64016, -15.999416, 2.9611568, ...
# 5598    [-353.46466, 102.151054, -14.645692, -11.56419...
# 5599    [-389.82825, 54.579174, 0.807547, -0.8762021, ...
# Name: speech, Length: 5600, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(123, return_sequences=False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2022-04-25 14:14:34.349739: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 123)               61500
# _________________________________________________________________
# dense (Dense)                (None, 64)                7936
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 71,747
# Trainable params: 71,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=100, batch_size=512, shuffle=True)
# Out:
# 2022-04-25 14:14:35.004111: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 9/9 [==============================] - 5s 226ms/step - loss: 1.8268 - accuracy: 0.3196 - val_loss: 2.0489 - val_accuracy: 0.1955
# Epoch 2/100
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5155 - accuracy: 0.5230 - val_loss: 1.9396 - val_accuracy: 0.1732
# Epoch 3/100
# 9/9 [==============================] - 1s 164ms/step - loss: 1.1229 - accuracy: 0.6292 - val_loss: 1.5614 - val_accuracy: 0.2545
# Epoch 4/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.8532 - accuracy: 0.6998 - val_loss: 1.3583 - val_accuracy: 0.3446
# Epoch 5/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.6576 - accuracy: 0.7739 - val_loss: 1.0208 - val_accuracy: 0.5634
# Epoch 6/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.5163 - accuracy: 0.8208 - val_loss: 0.7401 - val_accuracy: 0.7321
# Epoch 7/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.3878 - accuracy: 0.8674 - val_loss: 0.5773 - val_accuracy: 0.8214
# Epoch 8/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.3216 - accuracy: 0.8911 - val_loss: 0.4913 - val_accuracy: 0.8232
# Epoch 9/100
# 9/9 [==============================] - 2s 176ms/step - loss: 0.2751 - accuracy: 0.9080 - val_loss: 0.4171 - val_accuracy: 0.8562
# Epoch 10/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.2279 - accuracy: 0.9246 - val_loss: 0.3415 - val_accuracy: 0.9054
# Epoch 11/100
# 9/9 [==============================] - 1s 162ms/step - loss: 0.1857 - accuracy: 0.9400 - val_loss: 0.1988 - val_accuracy: 0.9464
# Epoch 12/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.1474 - accuracy: 0.9563 - val_loss: 0.1432 - val_accuracy: 0.9598
# Epoch 13/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.1254 - accuracy: 0.9627 - val_loss: 0.1440 - val_accuracy: 0.9545
# Epoch 14/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.1272 - accuracy: 0.9625 - val_loss: 0.1314 - val_accuracy: 0.9545
# Epoch 15/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.1314 - accuracy: 0.9596 - val_loss: 0.0992 - val_accuracy: 0.9661
# Epoch 16/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.1104 - accuracy: 0.9692 - val_loss: 0.1222 - val_accuracy: 0.9643
# Epoch 17/100
# 9/9 [==============================] - 2s 223ms/step - loss: 0.0843 - accuracy: 0.9759 - val_loss: 0.0907 - val_accuracy: 0.9732
# Epoch 18/100
# 9/9 [==============================] - 2s 170ms/step - loss: 0.0706 - accuracy: 0.9795 - val_loss: 0.0834 - val_accuracy: 0.9732
# Epoch 19/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0663 - accuracy: 0.9815 - val_loss: 0.0751 - val_accuracy: 0.9759
# Epoch 20/100
# 9/9 [==============================] - 1s 161ms/step - loss: 0.0599 - accuracy: 0.9835 - val_loss: 0.0728 - val_accuracy: 0.9795
# Epoch 21/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0557 - accuracy: 0.9828 - val_loss: 0.1202 - val_accuracy: 0.9661
# Epoch 22/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0644 - accuracy: 0.9801 - val_loss: 0.0946 - val_accuracy: 0.9696
# Epoch 23/100
# 9/9 [==============================] - 1s 169ms/step - loss: 0.0643 - accuracy: 0.9815 - val_loss: 0.0523 - val_accuracy: 0.9804
# Epoch 24/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0570 - accuracy: 0.9850 - val_loss: 0.0418 - val_accuracy: 0.9839
# Epoch 25/100
# 9/9 [==============================] - 1s 169ms/step - loss: 0.0541 - accuracy: 0.9853 - val_loss: 0.0558 - val_accuracy: 0.9821
# Epoch 26/100
# 9/9 [==============================] - 1s 157ms/step - loss: 0.0478 - accuracy: 0.9864 - val_loss: 0.0528 - val_accuracy: 0.9830
# Epoch 27/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0605 - accuracy: 0.9828 - val_loss: 0.0457 - val_accuracy: 0.9839
# Epoch 28/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0687 - accuracy: 0.9797 - val_loss: 0.0787 - val_accuracy: 0.9732
# Epoch 29/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 0.0516 - val_accuracy: 0.9812
# Epoch 30/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.0521 - accuracy: 0.9842 - val_loss: 0.0631 - val_accuracy: 0.9750
# Epoch 31/100
# 9/9 [==============================] - 2s 172ms/step - loss: 0.0544 - accuracy: 0.9857 - val_loss: 0.0369 - val_accuracy: 0.9884
# Epoch 32/100
# 9/9 [==============================] - 1s 159ms/step - loss: 0.0517 - accuracy: 0.9857 - val_loss: 0.0522 - val_accuracy: 0.9821
# Epoch 33/100
# 9/9 [==============================] - 1s 169ms/step - loss: 0.0397 - accuracy: 0.9871 - val_loss: 0.0658 - val_accuracy: 0.9804
# Epoch 34/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.0363 - accuracy: 0.9897 - val_loss: 0.0319 - val_accuracy: 0.9866
# Epoch 35/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0342 - accuracy: 0.9900 - val_loss: 0.0408 - val_accuracy: 0.9839
# Epoch 36/100
# 9/9 [==============================] - 1s 159ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.0274 - val_accuracy: 0.9875
# Epoch 37/100
# 9/9 [==============================] - 1s 162ms/step - loss: 0.0245 - accuracy: 0.9933 - val_loss: 0.0312 - val_accuracy: 0.9893
# Epoch 38/100
# 9/9 [==============================] - 2s 172ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 0.0180 - val_accuracy: 0.9929
# Epoch 39/100
# 9/9 [==============================] - 2s 172ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.0141 - val_accuracy: 0.9920
# Epoch 40/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0284 - accuracy: 0.9931 - val_loss: 0.0175 - val_accuracy: 0.9937
# Epoch 41/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0294 - accuracy: 0.9920 - val_loss: 0.0484 - val_accuracy: 0.9866
# Epoch 42/100
# 9/9 [==============================] - 1s 162ms/step - loss: 0.0189 - accuracy: 0.9946 - val_loss: 0.0151 - val_accuracy: 0.9955
# Epoch 43/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0184 - accuracy: 0.9958 - val_loss: 0.0316 - val_accuracy: 0.9857
# Epoch 44/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.0065 - val_accuracy: 0.9982
# Epoch 45/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0226 - accuracy: 0.9931 - val_loss: 0.0103 - val_accuracy: 0.9964
# Epoch 46/100
# 9/9 [==============================] - 2s 171ms/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.0337 - val_accuracy: 0.9857
# Epoch 47/100
# 9/9 [==============================] - 2s 176ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0253 - val_accuracy: 0.9902
# Epoch 48/100
# 9/9 [==============================] - 2s 175ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.0180 - val_accuracy: 0.9937
# Epoch 49/100
# 9/9 [==============================] - 2s 174ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0155 - val_accuracy: 0.9937
# Epoch 50/100
# 9/9 [==============================] - 2s 181ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.0234 - val_accuracy: 0.9902
# Epoch 51/100
# 9/9 [==============================] - 1s 168ms/step - loss: 0.0145 - accuracy: 0.9967 - val_loss: 0.0240 - val_accuracy: 0.9893
# Epoch 52/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0126 - accuracy: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9973
# Epoch 53/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0621 - val_accuracy: 0.9830
# Epoch 54/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0198 - val_accuracy: 0.9911
# Epoch 55/100
# 9/9 [==============================] - 1s 168ms/step - loss: 0.0135 - accuracy: 0.9967 - val_loss: 0.0039 - val_accuracy: 0.9982
# Epoch 56/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0106 - val_accuracy: 0.9937
# Epoch 57/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0122 - val_accuracy: 0.9955
# Epoch 58/100
# 9/9 [==============================] - 1s 170ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.0036 - val_accuracy: 0.9991
# Epoch 59/100
# 9/9 [==============================] - 2s 178ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0072 - val_accuracy: 0.9973
# Epoch 60/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0117 - val_accuracy: 0.9946
# Epoch 61/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0128 - val_accuracy: 0.9946
# Epoch 62/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 0.0042 - val_accuracy: 0.9973
# Epoch 63/100
# 9/9 [==============================] - 1s 160ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0404 - val_accuracy: 0.9884
# Epoch 64/100
# 9/9 [==============================] - 1s 159ms/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.0487 - val_accuracy: 0.9830
# Epoch 65/100
# 9/9 [==============================] - 1s 156ms/step - loss: 0.0328 - accuracy: 0.9913 - val_loss: 0.1454 - val_accuracy: 0.9589
# Epoch 66/100
# 9/9 [==============================] - 1s 159ms/step - loss: 0.0269 - accuracy: 0.9917 - val_loss: 0.0183 - val_accuracy: 0.9929
# Epoch 67/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0175 - accuracy: 0.9960 - val_loss: 0.0081 - val_accuracy: 0.9964
# Epoch 68/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0144 - val_accuracy: 0.9937
# Epoch 69/100
# 9/9 [==============================] - 2s 171ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 70/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0069 - val_accuracy: 0.9973
# Epoch 71/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0089 - val_accuracy: 0.9955
# Epoch 72/100
# 9/9 [==============================] - 1s 158ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0043 - val_accuracy: 0.9982
# Epoch 73/100
# 9/9 [==============================] - 1s 160ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 74/100
# 9/9 [==============================] - 1s 169ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 75/100
# 9/9 [==============================] - 2s 170ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0020 - val_accuracy: 0.9991
# Epoch 76/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0024 - val_accuracy: 0.9991
# Epoch 77/100
# 9/9 [==============================] - 1s 158ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 6.0914e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 9/9 [==============================] - 1s 160ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 79/100
# 9/9 [==============================] - 1s 165ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0038 - val_accuracy: 0.9991
# Epoch 80/100
# 9/9 [==============================] - 1s 154ms/step - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9973
# Epoch 81/100
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0224 - val_accuracy: 0.9911
# Epoch 82/100
# 9/9 [==============================] - 2s 170ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 83/100
# 9/9 [==============================] - 1s 169ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0193 - val_accuracy: 0.9946
# Epoch 84/100
# 9/9 [==============================] - 1s 157ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.0195 - val_accuracy: 0.9911
# Epoch 85/100
# 9/9 [==============================] - 1s 167ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0926 - val_accuracy: 0.9786
# Epoch 86/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.0308 - accuracy: 0.9933 - val_loss: 0.0162 - val_accuracy: 0.9946
# Epoch 87/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 0.0101 - val_accuracy: 0.9955
# Epoch 88/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0041 - val_accuracy: 0.9982
# Epoch 89/100
# 9/9 [==============================] - 2s 173ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 90/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0052 - val_accuracy: 0.9991
# Epoch 91/100
# 9/9 [==============================] - 1s 166ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.0095 - val_accuracy: 0.9955
# Epoch 92/100
# 9/9 [==============================] - 2s 170ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0018 - val_accuracy: 0.9991
# Epoch 93/100
# 9/9 [==============================] - 1s 156ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0015 - val_accuracy: 0.9991
# Epoch 94/100
# 9/9 [==============================] - 1s 168ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 2.8305e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 5.1456e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 9/9 [==============================] - 2s 176ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 5.1186e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 9/9 [==============================] - 2s 172ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 5.7787e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 1s 164ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 2.4536e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 1.5250e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 9/9 [==============================] - 2s 169ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 1.4964e-04 - val_accuracy: 1.0000

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(100))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
